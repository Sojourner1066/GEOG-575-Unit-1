# %%
import json
with open('WB_Electricity_Access.geojson') as gj:
    data = json.load(gj)

# %%
for i in data['features']:
    for year in range(1990,2015):
        year_field = f'YR{year}'
        x = i['properties'][year_field]
        # print(x,type(x))
        if x == 0.0
# Out:
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# None <class 'NoneType'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# 100.0 <class 'float'>
# ...

# %%
for i in data['features']:
    if i['properties']['YR1990'] == 0.0:
        print('found one')
        i['properties']['YR1990'] = None
